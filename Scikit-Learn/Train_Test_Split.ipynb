# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("500hits.csv", encoding="latin-1")

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df.info
# Out:
# <bound method DataFrame.info of              PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0           Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1       Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2      Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3       Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4      Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
# ..              ...  ...   ...    ...   ...   ...  ...  ...  ...   ...   ...
# 460        Jim Wynn   15  1920   6653  1105  1665  285   39  291   964  1224
# 461    Jorge Posada   17  1829   6092   900  1664  379   10  275  1065   936
# 462  Brady Anderson   15  1834   6499  1062  1661  338   67  210   761   960
# 463    Cookie Rojas   16  1822   6309   714  1660  254   25   54   593   396
# 464   Mickey Rivers   15  1468   5629   785  1660  247   71   61   499   266
#
# ...

# %%
X = df.drop(columns=["PLAYER", "HOF"])

# %%
y = df["HOF"]

# %%
X.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB   CS  \
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  178
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78   31
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  129
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358   97
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722   15
#
#       BA
# 0  0.366
# 1  0.331
# 2  0.345
# 3  0.310
# 4  0.329

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: HOF, dtype: int64

# %%
X.shape
# Out:
# (465, 14)

# %%
y.shape
# Out:
# (465,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11) #random_state = randomization uniform, test_size = 20%

# %%
X_train.shape
# Out:
# (372, 14)

# %%
X_test.shape
# Out:
# (93, 14)

# %%
X_train.describe()
# Out:
#               YRS            G            AB            R            H  \
# count  372.000000   372.000000    372.000000   372.000000   372.000000
# mean    17.010753  2046.521505   7526.077957  1154.126344  2177.994624
# std      2.662486   351.232903   1302.405807   291.308439   426.615256
# min     11.000000  1331.000000   4981.000000   651.000000  1660.000000
# 25%     15.000000  1797.500000   6507.500000   936.000000  1838.000000
# 50%     17.000000  1992.000000   7237.000000  1099.000000  2080.500000
# 75%     19.000000  2245.500000   8198.250000  1305.000000  2383.750000
# max     26.000000  3308.000000  12364.000000  2295.000000  4189.000000
#
#                2B          3B          HR          RBI           BB  \
# count  372.000000  372.000000  372.000000   372.000000   372.000000
# mean   382.505376   78.094086  202.642473   901.072581   780.104839
# std     97.173380   48.798439  141.726317   484.370314   327.453126
# ...

# %%
X_test.describe()
# Out:
#              YRS            G            AB            R            H  \
# count  93.000000    93.000000     93.000000    93.000000    93.000000
# mean   17.204301  2057.408602   7452.967742  1135.064516  2139.258065
# std     3.153877   368.580421   1265.371087   283.877148   415.164868
# min    11.000000  1399.000000   5472.000000   601.000000  1660.000000
# 25%    15.000000  1820.000000   6622.000000   935.000000  1818.000000
# 50%    17.000000  1997.000000   7359.000000  1108.000000  2054.000000
# 75%    19.000000  2282.000000   8096.000000  1283.000000  2256.000000
# max    25.000000  2850.000000  10876.000000  1859.000000  3430.000000
#
#                2B          3B          HR          RBI           BB  \
# count   93.000000   93.000000   93.000000    93.000000    93.000000
# mean   374.741935   80.397849  194.677419   867.010753   797.387097
# std     93.929310   51.791837  151.599814   495.127070   328.754568
# ...
